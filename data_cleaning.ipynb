# %%
import pandas as pd

data = {
    "Customer ID": [101, 102, 103, 104, 105, 101, 106, 107, 108, 109, 110],
    "Name": ["Nandini", "Ravi", "Sneha", "Arjun", "Priya", "Nandini", "Kiran", "Meena", "Rohit", "Anjali", "Teja"],
    "Village": ["Hyderabad", "Warangal", "Vijayawada", "Guntur", " Hyderabad ", "Hyderabad", "Visakhapatnam", None, "Tirupati", "Nellore", "Kurnool"],
    "Age": [21, 22, None, 24, 23, 21, 25, 22, None, 23, 24],
    "Phone Number": [9876543210, 9876543211, 9876543212, None, 9876543214, 9876543210, 9876543215, 9876543216, 9876543217, 9876543218, 9876543219],
    "Email": ["nandini@gmail.com", "ravi@gmail.com", "sneha@gmail.com", "arjun@gmail.com", "priya@gmail.com", "nandini@gmail.com", None, "meena@gmail.com", "rohit@gmail.com", "anjali@gmail.com", "teja@gmail.com"],
    "Purchase Amount": [5000, 3500, 4200, 3000, 4500, 5000, 5500, 3800, 4100, None, 4700]
}

df = pd.DataFrame(data)
df.to_csv("raw_data.csv", index=False)

print(df)
# Out:
#     Customer ID     Name        Village   Age  Phone Number  \
# 0           101  Nandini      Hyderabad  21.0  9.876543e+09
# 1           102     Ravi       Warangal  22.0  9.876543e+09
# 2           103    Sneha     Vijayawada   NaN  9.876543e+09
# 3           104    Arjun         Guntur  24.0           NaN
# 4           105    Priya     Hyderabad   23.0  9.876543e+09
# 5           101  Nandini      Hyderabad  21.0  9.876543e+09
# 6           106    Kiran  Visakhapatnam  25.0  9.876543e+09
# 7           107    Meena           None  22.0  9.876543e+09
# 8           108    Rohit       Tirupati   NaN  9.876543e+09
# 9           109   Anjali        Nellore  23.0  9.876543e+09
# 10          110     Teja        Kurnool  24.0  9.876543e+09
#
#                 Email  Purchase Amount
# 0   nandini@gmail.com           5000.0
# 1      ravi@gmail.com           3500.0
# 2     sneha@gmail.com           4200.0
# 3     arjun@gmail.com           3000.0
# 4     priya@gmail.com           4500.0
# ...

# %%
import pandas as pd

df = pd.read_csv("raw_data.csv")

print(df)
# Out:
#     Customer ID     Name        Village   Age  Phone Number  \
# 0           101  Nandini      Hyderabad  21.0  9.876543e+09
# 1           102     Ravi       Warangal  22.0  9.876543e+09
# 2           103    Sneha     Vijayawada   NaN  9.876543e+09
# 3           104    Arjun         Guntur  24.0           NaN
# 4           105    Priya     Hyderabad   23.0  9.876543e+09
# 5           101  Nandini      Hyderabad  21.0  9.876543e+09
# 6           106    Kiran  Visakhapatnam  25.0  9.876543e+09
# 7           107    Meena            NaN  22.0  9.876543e+09
# 8           108    Rohit       Tirupati   NaN  9.876543e+09
# 9           109   Anjali        Nellore  23.0  9.876543e+09
# 10          110     Teja        Kurnool  24.0  9.876543e+09
#
#                 Email  Purchase Amount
# 0   nandini@gmail.com           5000.0
# 1      ravi@gmail.com           3500.0
# 2     sneha@gmail.com           4200.0
# 3     arjun@gmail.com           3000.0
# 4     priya@gmail.com           4500.0
# ...

# %%
print(df.isnull().sum())
# Out:
# Customer ID        0
# Name               0
# Village            1
# Age                2
# Phone Number       1
# Email              1
# Purchase Amount    1
# dtype: int64

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 1

# %%
df = df.drop_duplicates()

print(df.shape)
# Out:
# (10, 7)

# %%
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].fillna("Unknown")

for col in df.select_dtypes(include=['number']).columns:
    df[col] = df[col].fillna(df[col].mean())

print(df)

# %%
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].str.strip()

print(df)
# Out:
#     Customer ID     Name        Village   Age  Phone Number  \
# 0           101  Nandini      Hyderabad  21.0  9.876543e+09
# 1           102     Ravi       Warangal  22.0  9.876543e+09
# 2           103    Sneha     Vijayawada   NaN  9.876543e+09
# 3           104    Arjun         Guntur  24.0           NaN
# 4           105    Priya      Hyderabad  23.0  9.876543e+09
# 6           106    Kiran  Visakhapatnam  25.0  9.876543e+09
# 7           107    Meena            NaN  22.0  9.876543e+09
# 8           108    Rohit       Tirupati   NaN  9.876543e+09
# 9           109   Anjali        Nellore  23.0  9.876543e+09
# 10          110     Teja        Kurnool  24.0  9.876543e+09
#
#                 Email  Purchase Amount
# 0   nandini@gmail.com           5000.0
# 1      ravi@gmail.com           3500.0
# 2     sneha@gmail.com           4200.0
# 3     arjun@gmail.com           3000.0
# 4     priya@gmail.com           4500.0
# 6                 NaN           5500.0
# ...

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

print(df.columns)
# Out:
# Index(['customer_id', 'name', 'village', 'age', 'phone_number', 'email',
#        'purchase_amount'],
#       dtype='object')

# %%
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].str.title()

print(df)
# Out:
#     customer_id     name        village   age  phone_number  \
# 0           101  Nandini      Hyderabad  21.0  9.876543e+09
# 1           102     Ravi       Warangal  22.0  9.876543e+09
# 2           103    Sneha     Vijayawada   NaN  9.876543e+09
# 3           104    Arjun         Guntur  24.0           NaN
# 4           105    Priya      Hyderabad  23.0  9.876543e+09
# 6           106    Kiran  Visakhapatnam  25.0  9.876543e+09
# 7           107    Meena            NaN  22.0  9.876543e+09
# 8           108    Rohit       Tirupati   NaN  9.876543e+09
# 9           109   Anjali        Nellore  23.0  9.876543e+09
# 10          110     Teja        Kurnool  24.0  9.876543e+09
#
#                 email  purchase_amount
# 0   Nandini@Gmail.Com           5000.0
# 1      Ravi@Gmail.Com           3500.0
# 2     Sneha@Gmail.Com           4200.0
# 3     Arjun@Gmail.Com           3000.0
# 4     Priya@Gmail.Com           4500.0
# 6                 NaN           5500.0
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      10 non-null     int64
#  1   name             10 non-null     object
#  2   village          9 non-null      object
#  3   age              8 non-null      float64
#  4   phone_number     9 non-null      float64
#  5   email            9 non-null      object
#  6   purchase_amount  9 non-null      float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 640.0+ bytes
# None

# %%
df.to_csv("cleaned_data.csv", index=False)

print("Data Cleaning Completed Successfully!")
# Out:
# Data Cleaning Completed Successfully!

# %%
print(df.head())
# Out:
#    customer_id     name     village   age  phone_number              email  \
# 0          101  Nandini   Hyderabad  21.0  9.876543e+09  Nandini@Gmail.Com
# 1          102     Ravi    Warangal  22.0  9.876543e+09     Ravi@Gmail.Com
# 2          103    Sneha  Vijayawada   NaN  9.876543e+09    Sneha@Gmail.Com
# 3          104    Arjun      Guntur  24.0           NaN    Arjun@Gmail.Com
# 4          105    Priya   Hyderabad  23.0  9.876543e+09    Priya@Gmail.Com
#
#    purchase_amount
# 0           5000.0
# 1           3500.0
# 2           4200.0
# 3           3000.0
# 4           4500.0
